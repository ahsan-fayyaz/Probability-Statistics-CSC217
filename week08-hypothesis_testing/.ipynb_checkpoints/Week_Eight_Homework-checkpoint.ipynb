# %% [markdown]
# The income per capita per US State in 2018 is approximately a normal distribution with a mean of \$48,500 and a standard deviation of $8,500.
#
# 1) Create a PDF graph of this distribution with the proper labels on the axes.
#
# 2) Say we wanted to create a rejection region for any states with below average
#    income. If we set the rejection region at 40,000, what would the percentile
#    value of that be given the distribution?
#
# 3) Say that I'm a Senator from New York, which has an income per capita of \$64,500.
#
#    I believe that my state has an income that's conceivably different from the rest of the country - so different that I could convince someone that we're not even part of the United States. I want to use hypothesis testing to prove it.
#
#    Note that I am not surveying people - this is a single data point. In this case:
#
#        a) What is the null hypothesis?
#
#        b) What is the alternative hypothesis?
#
#        c) Say I want to do a two-tailed test at a significance level of 0.05 to see if
#        my hypothesis is true. What is my rejection region? Can I reject the null hypothesis here?
#
#        d) Seeing that the average income per capita for New York is obviously higher than the
#        income per capita for the United States, I want to change my test to a one-tailed test.
#
#        At the 0.05 significance level, what is my rejection region? Can I reject the null hypothesis here?
#
#        e) Say I want to keep the test one-tailed, but change my significance level to 0.01. What is my rejection region now? Can I reject the null hypothesis here?
#
# 4) Say now that I don't actually know the distribution of the income per capita per US State - I'm just making it up to sound smart. But I do survey ten state representatives from New York and get the following data points for income per capita of our state:
# [62837, 64511, 58821, 63971, 62837, 57084, 64579, 62837, 58821,
#        63971]
#
#         a) What is the sample mean for this distribution?
#         b) What is the sample variance and sample standard deviation for this distribution?
#         c) Say I again want to see if I can reject the null hypothesis that the income per capita for New York
#         is the same as the income per capita for the United States.
#
#            Note that this is based off of a survey of ten, so we would want to effectively see if the ten people we surveyed could have effectively been pulled from anywhere in the US, not just New York.
#         d) Given a T-distribution with a mean of 50,000, our sample standard deviation, and nine degrees of freedom, what is the one-tailed rejection region at the 0.01 significance level? Can we reject the null hypothesis that New York has a different income per capita than the rest of the United States? Note that we are using our sample mean to determine this, not the previously stated value of $64,500.
#
# 5) This information was actually pulled from the Wikipedia here - https://en.wikipedia.org/wiki/List_of_U.S._states_by_GDP_per_capita.
# Using the pd.read_html function, read in the table of U.S. State by GDP capita and plot a histogram and boxplot of the 2018 data in the first table. Are there any outliers, and if so, which states are outliers?
#
# BONUS 6) Remove the outlier (if there is one), and replot a histogram and boxplot of the data. Are there any outliers now?

# %%
import scipy.stats as stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import statistics as st
#df = pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._states_by_GDP_per_capita', header=0)[0]
#

# %% [markdown]
# The income per capita per US State in 2018 is approximately a normal distribution with a mean of \$48,500 and a standard deviation of $8,500.

# %% [markdown]
# ### 1) Create a PDF graph of this distribution with the proper labels on the axes.

# %%
#1: PDF Graph with Mean 48500 and standard deviation of 8500
dist = stats.norm(48500, 8500)
fig = plt.figure(figsize=(15,10))
x = np.linspace(dist.ppf(0.0001), dist.ppf(0.9999), 100)
plt.plot(x, dist.pdf(x))
plt.ylim(bottom=0)
plt.xlabel('Income per capita')
plt.ylabel('Probability Density Function')
fig.suptitle('Income per capita per US state in 2018', fontsize=15, y=0.92)
# Out:
# Text(0.5, 0.92, 'Income per capita per US state in 2018')

# %% [markdown]
# ### 2) Say we wanted to create a rejection region for any states with below average income. If we set the rejection region at 40,000, what would the percentile value of that be given the distribution?

# %%
stats.norm(48500,8500).cdf(40000)
# Out:
# 0.15865525393145707

# %% [markdown]
# 3) Say that I'm a Senator from New York, which has an income per capita of $64,500.
#
# I believe that my state has an income that's conceivably different from the rest of the country - so different that I could convince someone that we're not even part of the United States. I want to use hypothesis testing to prove it.
#
# Note that I am not surveying people - this is a single data point. In this case:
#
# ###   a) What is the null hypothesis?

# %% [markdown]
# Answer: My state has income that is similar to rest of the country.

# %% [markdown]
# ###       b) What is the alternative hypothesis?

# %% [markdown]
# Answer: My state has income that's conceibably different from the rest of the country.

# %% [markdown]
# ###       c) Say I want to do a two-tailed test at a significance level of 0.05 to see if my hypothesis is true. What is my rejection region? Can I reject the null hypothesis here?

# %% [markdown]
# Answer:
# This means that our rejection region is 0.025 on either sides,
# and our confidence level is 95% or 0.95
# From the table, we can see that our z-score for 0.95 is 1.960
#
# THE REJECTION REGION is:
# region > 1.960
# region < -1.960
#
# z = value - mean / standard deviation

# %%
z = (64500 - 48500)
x = 8500/math.sqrt(50)
z/x
# Out:
# 13.310245292923248

# %% [markdown]
# ### Here our z score = 13.3
#
# #### Which is definitely greater than 1.960
# #### So the answer is we CAN reject null hypothesis here

# %% [markdown]
# ###             d) Seeing that the average income per capita for New York is obviously higher than the income per capita for the United States, I want to change my test to a one-tailed test.       At the 0.05 significance level, what is my rejection region? Can I reject the null hypothesis here?

# %% [markdown]
# Answer: This means our rejection region is 0.05 on the right side, and our confidence level is now 95%
# Our z-score now is 2.1
#
# The rejection region is:
# region > 2.132
# z score is 13

# %% [markdown]
# We reject the NULL hypothesis here

# %% [markdown]
# ### 4)
# Say now that I don't actually know the distribution of the income per capita per US State - I'm just making it up to sound smart. But I do survey ten state representatives from New York and get the following data points for income per capita of our state:
# [62837, 64511, 58821, 63971, 62837, 57084, 64579, 62837, 58821,
#        63971]
#
#         a) What is the sample mean for this distribution?
#         b) What is the sample variance and sample standard deviation for this distribution?
#         c) Say I again want to see if I can reject the null hypothesis that the income per capita for New York
#         is the same as the income per capita for the United States.
#         Note that this is based off of a survey of ten, so we would want to effectively see if the ten people we surveyed could have effectively been pulled from anywhere in the US, not just New York.

# %%
#a)
sample_mean = [62837, 64511, 58821, 63971, 62837, 57084, 64579, 62837, 58821, 63971]
sum = 0
count = 0
for i in sample_mean:
    sum += i
    count += 1
print("The sample mean is: ")
print(sum/count)
# Out:
# The sample mean is:
# 62026.9

# %%
#b)standard deviation
std_dev = st.stdev(sample_mean)
print("The standard deviation is", std_dev)
# Out:
# The standard deviation is 2732.513147269378

# %%
print("The variance is ", std_dev**2)
# Out:
# The variance is  7466628.100000001

# %% [markdown]
# ### 5) This information was actually pulled from the Wikipedia here - https://en.wikipedia.org/wiki/List_of_U.S._states_by_GDP_per_capita. Using the pd.read_html function, read in the table of U.S. State by GDP capita and plot a histogram and boxplot of the 2018 data in the first table. Are there any outliers, and if so, which states are outliers?

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of
# 14   50148   48884
# 15   49569   47973
# 16   49254   49731
# 17   48388   47265
# 18   51946   51389
# 19   49418   48549
# 20   46387   45312
# 21   49601   47530
# 22   47287   46680
# 23   45884   45195
# 24   45605   45457
# 25   46332   45280
# 26   42667   41593
# 27   44126   43215
# 28   44243   43770
# 29   42996   40572
# 30   42029   42052
# 31   41500   41563
# 32   38303   38640
# 33   43141   43160
# 34   42170   40855
# 35   48599   46949
# 36   44589   44774
# 37   38763   36676
# 38   42204   42012
# 39   39370   39096
# 40   40297   40670
# 41   38604   38695
# 42   37733   36667
# 43   37579   36209
# 44   38352   37910
# 45   37935   38232
# 46   35913   35376
# 47   35126   34955
# 48   34671   33837
# 49   35368   34564
# 50   34620   34664
# 51   31688   31658

# %%
fig = plt.figure(figsize=(15,10))
plt.hist(df['2018'])
# Out:
# (array([22., 22.,  7.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 31881. ,  44740.1,  57599.2,  70458.3,  83317.4,  96176.5,
#         109035.6, 121894.7, 134753.8, 147612.9, 160472. ]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure(figsize=(15,15))
plt.boxplot(df['2018'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2c01342668>,
#   <matplotlib.lines.Line2D at 0x7f2c013429b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2c01342d30>,
#   <matplotlib.lines.Line2D at 0x7f2c01342e10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2c01342240>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2c0134b400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2c0134b748>],
#  'means': []}

# %% [markdown]
# #### There is one outlier here with the value =  160472

# %% [markdown]
# ### BONUS 6) Remove the outlier (if there is one), and replot a histogram and boxplot of the data. Are there any outliers now?

# %% [markdown]
# To drop the outliers:

# %%
new_data = df.drop(df.index[0])
new_data
# Out:
#    Rank           State   2018   2017   2016   2015   2014   2013   2012  \
# 1     1   Massachusetts  65545  64507  62510  61882  62456  61769  60808
# 2     2        New York  64579  64093  63420  62444  62841  61185  61267
# 3     3     Connecticut  64511  63747  62236  62550  63502  63638  64906
# 4     4          Alaska  63971  67705  67411  69700  73478  70573  69564
# 5     5        Delaware  63664  64040  63271  60719  62174  63793  62837
# 6     6    North Dakota  62837  67305  71056  67651  68105  57066  52185
# 7     7         Wyoming  58821  60908  61417  60770  60777  63985  64603
# 8     8      California  53987  57328  55374  53855  52974  52099  51871
# 9     9      New Jersey  57084  56472  55635  55750  55161  54302  55023
# 10   10      Washington  56831  55780  55001  54161  53439  52500  52679
# 11   11        Maryland  55404  54894  54003  53765  54018  54209  53675
# 12   12        Illinois  54091  53432  52795  51963  52172  51198  50304
# 13   13           Texas  53795  54421  52993  52018  50266  48354  47417
# 14   14       Minnesota  53704  53380  53005  51999  51272  50875  50148
# 15   15        Nebraska  53114  52878  53099  51565  50631  51360  49569
# 16   16        Colorado  52795  52622  52019  50475  49639  49285  49254
# 17   17   New Hampshire  51794  50456  49480  48871  48652  48504  48388
# 18   18        Virginia  51736  51716  50803  51106  51546  51754  51946
# 19   19          Hawaii  51277  50320  49497  49539  49513  49331  49418
# 20   20    Pennsylvania  50997  50418  49155  48278  47540  46872  46387
# 21   21          Oregon  50582  49792  48342  48094  49395  51266  49601
# 22    —   United States  50577  50155  49253  48538  48173  47595  47287
# 23   22            Iowa  50315  50086  49218  48002  48001  46523  45884
# 24   23    South Dakota  48076  47706  46776  46869  46965  47972  45605
# 25   24    Rhode Island  47639  47118  46668  46356  46188  46010  46332
# 26   25            Ohio  47567  46826  46385  45254  44896  44192  42667
# 27   26       Wisconsin  47266  46859  46340  45845  45382  44906  44126
# 28   27          Kansas  46982  46890  46003  45470  45514  45476  44243
# 29   28         Indiana  45317  44797  44577  43866  43064  43058  42996
# 30   29         Georgia  44723  43913  43313  42500  42191  42140  42029
# 31   30            Utah  44636  44204  43069  42267  41929  41992  41500
# 32   31        Oklahoma  44623  45864  45007  43288  41861  39961  38303
# 33   32  North Carolina  44325  44096  43372  42945  42659  43223  43141
# 34   33         Vermont  43946  43495  43039  42914  43042  43124  42170
# 35   34       Louisiana  43917  44293  44254  43725  45482  45712  48599
# 36   35          Nevada  43820  43649  42927  43075  43382  44555  44589
# 37   36        Michigan  43372  42631  41514  40993  40463  39757  38763
# 38   37        Missouri  43317  42943  42442  42487  41926  41598  42204
# 39   38       Tennessee  43267  42797  41828  41487  41091  40193  39370
# 40   39      New Mexico  41348  41577  40842  39659  40094  40167  40297
# 41   40         Florida  39543  39093  38398  38023  37705  37876  38604
# 42   41         Montana  39356  39686  39214  38476  38537  38542  37733
# 43   42        Kentucky  38985  38603  38298  38247  38052  37926  37579
# 44   43           Maine  38921  38450  38014  37477  37705  37780  38352
# 45   44         Arizona  38590  38414  38427  38303  38559  38257  37935
# 46   45         Alabama  37261  36856  36538  36660  36425  36201  35913
# 47   46  South Carolina  37063  36796  36295  35701  35346  35609  35126
# 48   47        Arkansas  36368  36196  36249  35865  34965  35146  34671
# 49   48   West Virginia  36315  36453  36161  35755  35509  36084  35368
# 50   49           Idaho  35466  35467  35099  34748  34094  34270  34620
# 51   50     Mississippi  31881  31633  31522  31923  31786  31167  31688
#
#      2011
# 1   59178
# 2   59481
# 3   65574
# 4   72204
# 5   64313
# 6   48858
# 7   66320
# 8   51733
# 9   55067
# 10  52264
# 11  52515
# 12  49859
# 13  47034
# 14  48884
# 15  47973
# 16  49731
# 17  47265
# 18  51389
# 19  48549
# 20  45312
# 21  47530
# 22  46680
# 23  45195
# 24  45457
# 25  45280
# 26  41593
# 27  43215
# 28  43770
# 29  40572
# 30  42052
# 31  41563
# 32  38640
# 33  43160
# 34  40855
# 35  46949
# 36  44774
# 37  36676
# 38  42012
# 39  39096
# 40  40670
# 41  38695
# 42  36667
# 43  36209
# 44  37910
# 45  38232
# 46  35376
# 47  34955
# 48  33837
# 49  34564
# 50  34664
# 51  31658

# %% [markdown]
# This is a new dataset with removed outlier

# %%
fig = plt.figure(figsize=(15,10))
plt.hist(new_data['2018'])
# Out:
# (array([ 1.,  6.,  5., 11.,  5.,  7.,  7.,  2.,  1.,  6.]),
#  array([31881. , 35247.4, 38613.8, 41980.2, 45346.6, 48713. , 52079.4,
#         55445.8, 58812.2, 62178.6, 65545. ]),
#  <a list of 10 Patch objects>)

# %%
fig = plt.figure(figsize=(15,15))
plt.boxplot(new_data['2018'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f2c01283e48>,
#   <matplotlib.lines.Line2D at 0x7f2c01283f28>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f2c0128b550>,
#   <matplotlib.lines.Line2D at 0x7f2c0128b898>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f2c01283a20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f2c0128bbe0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f2c0128bf28>],
#  'means': []}
